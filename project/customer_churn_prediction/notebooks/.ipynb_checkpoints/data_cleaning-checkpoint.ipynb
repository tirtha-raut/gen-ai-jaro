# %%
import pandas as pd

# Load raw data
df = pd.read_csv("../data/raw/ConnectTel_Churn_Intelligence-1.csv")

# Basic inspection
df.head()
df.info()
df.describe()

# Check missing values
df.isnull().sum()

# Check duplicates
df.duplicated().sum()

# Remove duplicates (if any)
df = df.drop_duplicates()

# Save cleaned dataset
df.to_csv("../data/processed/customer_churn_cleaned.csv", index=False)
