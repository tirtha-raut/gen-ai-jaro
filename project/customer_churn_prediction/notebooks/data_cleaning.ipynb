# %%
import pandas as pd

# Load raw data
df = pd.read_csv("../data/raw/ConnectTel_Churn_Intelligence.csv")

# Basic inspection
df.head()
df.info()
df.describe()

# Check missing values
df.isnull().sum()

# Check duplicates
df.duplicated().sum()

# Remove duplicates (if any)
df = df.drop_duplicates()

# Save cleaned dataset
df.to_csv("../data/processed/customer_churn_cleaned.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50500 entries, 0 to 50499
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 50500 non-null  int64
#  1   customer_age                50500 non-null  int64
#  2   gender                      50500 non-null  object
#  3   city                        50500 non-null  object
#  4   customer_tenure_months      50500 non-null  int64
#  5   customer_segment            50500 non-null  object
#  6   plan_type                   50500 non-null  object
#  7   monthly_bill_amount         50500 non-null  float64
#  8   contract_type               50500 non-null  object
#  9   number_of_services          50500 non-null  int64
#  10  monthly_data_usage_gb       50500 non-null  float64
#  11  monthly_voice_minutes       50500 non-null  float64
#  12  monthly_sms_count           50500 non-null  int64
#  13  international_usage_flag    50500 non-null  int64
#  14  network_drop_rate           50500 non-null  float64
#  15  average_download_speed      45361 non-null  float64
#  16  service_outages_last_6m     50500 non-null  int64
#  17  support_tickets_last_12m    50500 non-null  int64
#  18  avg_resolution_time_hours   50500 non-null  float64
#  19  complaints_last_12m         50500 non-null  int64
#  20  mobile_app_logins_last_30d  50500 non-null  int64
#  21  reward_points_balance       50500 non-null  int64
#  22  campaign_response_rate      45454 non-null  float64
#  23  late_payments_last_12m      50500 non-null  int64
#  24  autopay_enabled             50500 non-null  int64
#  25  billing_disputes_last_12m   50500 non-null  int64
#  26  customer_lifetime_value     50500 non-null  float64
#  27  monthly_revenue             50500 non-null  float64
#  28  retention_offer_count       50500 non-null  int64
#  29  legacy_customer_code        50500 non-null  int64
#  30  service_region_cluster      50500 non-null  int64
#  31  crm_reference_number        50500 non-null  int64
#  32  marketing_batch_id          50500 non-null  int64
#  33  churn_flag                  50500 non-null  int64
# dtypes: float64(9), int64(20), object(5)
# memory usage: 13.1+ MB
